# %%
pd.__version__
# Out:
# '1.5.3'

# %%
import pandas as pd

df = pd.read_csv("tweets.csv")
df["name"] = pd.Series(df["name"]).str.lower()
df["date_time"] = pd.to_datetime(df["date_time"])
df = (
    df.groupby([df["date_time"].dt.date, "name"])[
        ["number_of_likes", "number_of_shares"]
    ]
    .mean()
    .astype(int)
)
df = df.reset_index()

df.head()
# Out:
#     date_time         name  number_of_likes  number_of_shares
# 0  2010-01-06  selenagomez              278               695
# 1  2010-01-07  jtimberlake               62               189
# 2  2010-01-07  selenagomez              201               630
# 3  2010-01-08  jtimberlake               27               107
# 4  2010-01-08  selenagomez              349               935

# %%
# Out:
#    index       name                                            content  \
# 0      0  katyperry  Is history repeating itself...?#DONTNORMALIZEH...
# 1      1  katyperry  @barackobama Thank you for your incredible gra...
# 2      2  katyperry                Life goals. https://t.co/XIn1qKMKQl
# 3      3  katyperry            Me right now 🙏🏻 https://t.co/gW55C1wrwd
# 4      4  katyperry  SISTERS ARE DOIN' IT FOR THEMSELVES! 🙌🏻💪🏻❤️ ht...
#
#   country           date_time            id language  number_of_likes  \
# 0     NaN 2017-12-01 19:52:00  8.200000e+17       en             7900
# 1     NaN 2017-11-01 08:38:00  8.190000e+17       en             3689
# 2     NaN 2017-11-01 02:52:00  8.190000e+17       en            10341
# 3     NaN 2017-11-01 02:44:00  8.190000e+17       en            10774
# 4     NaN 2017-10-01 05:22:00  8.190000e+17       en            17620
#
#    number_of_shares
# 0              3472
# 1              1380
# 2              2387
# 3              2458
# 4              4655

# %%
import pandas as pd

# Sample data
data = {
    'Category': ['A', 'B', 'A', 'B', 'A', 'C'],
    'Month': ['Jan', 'Jan', 'Feb', 'Feb', 'Mar', 'Mar'],
    'Value': [10, 15, 20, 25, 30, 35]
}

df = pd.DataFrame(data)

# Group by multiple columns and calculate the mean
grouped = df.groupby(['Category', 'Month'])
result = grouped['Value'].mean()
result.head()
# Out:
# Category  Month
# A         Feb      20.0
#           Jan      10.0
#           Mar      30.0
# B         Feb      25.0
#           Jan      15.0
# Name: Value, dtype: float64
